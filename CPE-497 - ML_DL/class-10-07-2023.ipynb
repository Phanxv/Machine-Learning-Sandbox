# %% [markdown]
# ### K-NN

# %%
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# %%
x = np.array([112,130,148,151,168,189,218,247,315,350])
y = np.array([225,200,459,445,439,577,722,903,1350,1360])

slope, intercept, r, p, std_err = stats.linregress(x,y)

# %%
def myfunc(x) :
    return slope * x + intercept

my_model = list(map(myfunc,x))
print("Regression Line is Y =", str(slope), 'X +', str(intercept))
plt.scatter(x,y)
plt.plot(x, my_model)
plt.show()
# Out:
# Regression Line is Y = 5.1883007204732134 X + -384.1873861119677

# %% [markdown]
# ### SVM - Linear SVC

# %% [markdown]
# #### 1.

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import svm 
from sklearn.datasets import make_blobs 

X = np.array([[3,1],[3,-1],[6,1],[6,-1],[1,0],[0,1],[0,-1],[-1,0]]) 
y = np.array([1,1,1,1,0,0,0,0]) 

plt.scatter(X[:,0], X[:,1],c=y, s=30, cmap=plt.cm.Paired)

clf = svm.SVC(kernel='linear', C=1000)
clf.fit(X,y)

ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()
xx = np.linspace(xlim[0], xlim[1], 50)
yy = np.linspace(ylim[0], ylim[1], 50)
YY,XX = np.meshgrid(yy,xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)

ax.contour(XX, YY, Z, colors = 'k', levels = [-1,0,1], alpha = 0.7, linestyles = ['--','-','--'])

ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:,1], s = 100, linewidths=1, facecolors='none', edgecolors='k')

plt.show()

# %% [markdown]
# #### 3.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs


# we create 40 separable points
X, y = make_blobs(n_samples=40, centers=2, random_state=6)

clf = svm.SVC(kernel='linear', C=1000)
clf.fit(X, y)

plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=plt.cm.Paired)
ax = plt.gca()
xlim = ax.get_xlim() 
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30) 
yy = np.linspace(ylim[0], ylim[1], 30) 
YY, XX = np.meshgrid(yy,xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)

ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, 
     linestyles=["--",'-', '--'])
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], 5-100,      
           linewidth=1, facecolors='none', edgecolors='k')
plt.show()
# Out:
# /home/phanxv/miniconda3/envs/classDev/lib/python3.9/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# #### 4.

# %%
from sklearn.svm import LinearSVC, SVC
from sklearn.linear_model import SGDClassifier
import matplotlib.pyplot as plt

# %%
d1 = np.concatenate((np.random.normal(loc=6, scale=1, size=(500,2)), np.ones((500,1))), axis=1)
d2 = np.concatenate((np.random.normal(loc=3, scale=1, size=(500,2)), np.zeros((500,1))), axis=1)
d1.shape, d2.shape
# Out:
# ((500, 3), (500, 3))

# %%
plt.scatter(d1[:,0], d1[:,1], c='red')
plt.scatter(d2[:,0], d2[:,1], c='blue')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Synthetic 2D points')
plt.xlim(0,10)
plt.ylim(0,10)
plt.show()
